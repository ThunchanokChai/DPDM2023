# %% [markdown]
# <a href="https://colab.research.google.com/github/ThunchanokChai/DPDM2023/blob/main/midterm_dpdm2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Use the latest Thai's general election data here https://docs.google.com/spreadsheets/d/1fROfZuM7150UjGEQksRMkoVxZ4dBYDTR/edit?usp=share_link&ouid=115237908096743617902&rtpof=true&sd=true
#
# (***Thai's general election detail***: Of the 500 members of the House of Representatives to be elected, 400 seats are elected from single-member constituencies by first-past-the-post voting, and 100 party-list seats—filled separately—are voted on in a separate ballot. ELECTED constituency candidate is the constituency candidate who recieved the highest votes, the party list is vote for the party)
#
# to write excutable codes for the following instructions,
#
#
# 1. create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by the number of votes they received and showed only top 10 (30 points)
# 2. create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by voted they received and showed only 5 worst perform (30 points)
# 3. create a table from the party list vote result that shows the ratio between the vote recieved by the highest party and the second highest party of each constituency area.
#
#  ($\frac{V1}{V2}$ where $V1$ is the number of votes the highest paty received and $V2$ is the number of votes the second highest paty received)
#
# The table should include name of the constituency area, district, province, name of the top party, name of the runner-up party, and $\frac{V1}{V2}$
# (60 points)
#
# Full score 100 points (bonus 20 points)

# %% [markdown]
# ##Import Data

# %%
from google.colab import drive # เชื่อม google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
#ผลการเลือกตั้งแบบแบ่งเขต
result_constituencies_Candidate = pd.read_csv('/content/drive/MyDrive/DPDM23_DATA/result_constituencies_Candidate.csv') # result_constituencies_Candidate

# %%
Candidate_Constituency = pd.read_csv('/content/drive/MyDrive/DPDM23_DATA/Candidate_Constituency.csv') #ข้อมูลผู้สมัครแบ่งเขต

# %%
info_party= pd.read_csv('/content/drive/MyDrive/DPDM23_DATA/info_party_overview.csv') #ข้อมูลพรรค

# %%
#ผลการเลือกตั้งแบบบัญชีรายชื่อ
result_constituencies_PartyList = pd.read_csv('/content/drive/MyDrive/DPDM23_DATA/result_constituencies_PartyList.csv')

# %% [markdown]
# ###Q1
# create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by the number of votes they received and showed only top 10 (30 points)

# %%
# Show ผู้สมัคร 10 อันดับแรก ของแต่ละเขต
result_constituencies_Candidate_Top10 = result_constituencies_Candidate[result_constituencies_Candidate['mp_app_rank'] < 11]

# %%
result_constituencies_Candidate_Top10.describe() #จะเห็นได้ว่าค่าmax ของ mp_app_rank มีค่ามากที่สุด คือ 10
# Out:
#        mp_app_rank   mp_app_vote  mp_app_vote_percent     party_id
# count  3926.000000   3926.000000          3926.000000  3926.000000
# mean      5.420530   9284.364748             9.970789   731.247835
# std       2.838799  13118.060070            20.764284    23.907581
# min       1.000000      0.000000             0.000000   701.000000
# 25%       3.000000    491.000000             0.503238   709.000000
# 50%       5.000000   1366.500000             1.392290   726.000000
# 75%       8.000000  15847.500000            16.456080   762.000000
# max      10.000000  63185.000000           714.909760   786.000000

# %%
result_constituencies_Candidate_Top10
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1   ACR_1_1            9          459              0.43477
# 1      ACR_1  ACR_1_10            1        38275             36.25419
# 5      ACR_1   ACR_1_2           10          234              0.22165
# 6      ACR_1   ACR_1_3            6         2701              2.55840
# 7      ACR_1   ACR_1_4            8          668              0.63273
# ...      ...       ...          ...          ...                  ...
# 4775   YST_3   YST_3_4            5         4957              4.74209
# 4776   YST_3   YST_3_5            1        37946             36.30085
# 4777   YST_3   YST_3_6            7          821              0.78541
# 4778   YST_3   YST_3_7            9          531              0.50798
# 4780   YST_3   YST_3_9            3        14502             13.87326
#
#       party_id
# 0          706
# 1          709
# 5          769
# 6          763
# 7          719
# ...        ...
# ...

# %%
#จากข้อมูลผู้สมัครทั้งหมด
Candidate_Constituency
# Out:
#      mp_app_id             mp_app_name  mp_app_no  mp_app_party_id  \
# 0      ACR_1_1   นางสาวปิยะมาศ บัวแก้ว          1              706
# 1     ACR_1_10  นางสุขสมรวย วันทนียกุล         10              709
# 2     ACR_1_11     นายการันต์ ลุนพันธ์         11              712
# 3     ACR_1_12          นายไสว ผลาวงศ์         12              742
# 4     ACR_1_13        นายสงบ โสภิพันธ์         13              761
# ...        ...                     ...        ...              ...
# 4776   YST_3_5       นายธนพัฒน์ ศรีชนะ          5              709
# 4777   YST_3_6        นายพิทยา พาลุสุข          6              763
# 4778   YST_3_7      นายศรายุทธ สุดสวาท          7              712
# 4779   YST_3_8    นางสาวสุนันทา สีชมภู          8              769
# 4780   YST_3_9        นายณัฐพล ศรีอุบล          9              726
#
#                                               image_url
# 0     https://cdn.ectreport.com/images/mp_candidates...
# ...

# %%
#สร้างตารางโดยแสดงเฉพาะชื่อและหมายเลขผู้สมัครสส จากข้อมูลผู้สมัครทั้งหมด
Candidate_name=Candidate_Constituency[['mp_app_id','mp_app_name']]

# %%
Candidate_name.head()
# Out:
#   mp_app_id             mp_app_name
# 0   ACR_1_1   นางสาวปิยะมาศ บัวแก้ว
# 1  ACR_1_10  นางสุขสมรวย วันทนียกุล
# 2  ACR_1_11     นายการันต์ ลุนพันธ์
# 3  ACR_1_12          นายไสว ผลาวงศ์
# 4  ACR_1_13        นายสงบ โสภิพันธ์

# %%
#หาชื่อของผู้ลงสมัครในแต่ละเขตจากหมายเลขผู้สมัคร
result_constituencies_Top10_name_Candidate=pd.merge(result_constituencies_Candidate_Top10, Candidate_name, on='mp_app_id')

# %%
info_party #ข้อมูลต่างๆของแต่ละพรรค
# Out:
#     party_id  party_no           name    abbr    color  \
# 0        701      26.0   ประชาธิปัตย์    ปชป.  #06aff3
# 1        702      63.0     ประชากรไทย    ปชท.  #0f41ce
# 2        703      60.0   ความหวังใหม่    ควม.  #e6b750
# 3        705      29.0       เพื่อไทย     พท.  #da3731
# 4        706      14.0  ชาติพัฒนากล้า    ชพก.  #233e8a
# ..       ...       ...            ...     ...      ...
# 65       780      55.0    ไทยก้าวหน้า    ทกน.  #b9bee3
# 66       781       9.0           พลัง      พ.  #8e8fc7
# 67       783      52.0  ชาติรุ่งเรือง    ชรร.  #9cb4c9
# 68       784      23.0       รวมใจไทย  ร.จ.ท.  #eec49a
# 69       786      20.0        เปลี่ยน      ป.  #cc898a
#
#                                              logo_url
# 0   https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1   https://cdn.ectreport.com/images/logos/ประชากร...
# 2   https://cdn.ectreport.com/images/logos/ความหวั...
# 3   https://cdn.ectreport.com/images/logos/เพื่อไท...
# ...

# %%
#สร้างตารางโดยแสดงเฉพาะชื่อพรรคและหมายเลขพรรค จากข้อมูล่างๆของแต่ละพรรค
party_name=info_party[['party_id','name']] #สร้างตารางใหม่จากข้อมูลพรรค โดยเอามาเฉพาะ รหัสพรรคและชื่อพรรค

# %%
party_name
# Out:
#     party_id           name
# 0        701   ประชาธิปัตย์
# 1        702     ประชากรไทย
# 2        703   ความหวังใหม่
# 3        705       เพื่อไทย
# 4        706  ชาติพัฒนากล้า
# ..       ...            ...
# 65       780    ไทยก้าวหน้า
# 66       781           พลัง
# 67       783  ชาติรุ่งเรือง
# 68       784       รวมใจไทย
# 69       786        เปลี่ยน
#
# [70 rows x 2 columns]

# %%
#รวมชื่อพรรคเข้าไปในตารางโดยรวมจาก party_id
result_constituencies_Top10=pd.merge(result_constituencies_Top10_name_Candidate, party_name, on='party_id')

# %%
result_constituencies_Top10 #จะได้ ชื่อของผู้สมัครและพรรคที่ได้คะแนนโหวต 10 อันดับแรก
# Out:
#      cons_id  mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1    ACR_1_1            9          459              0.43477
# 1      BKK_1    BKK_1_9            7         1247              1.32088
# 2     BKK_10   BKK_10_1            7          751              0.72144
# 3     BKK_11  BKK_11_10            9          402              0.39176
# 4     BKK_12  BKK_12_14            7         1077              1.01212
# ...      ...        ...          ...          ...                  ...
# 3921   SRN_1   SRN_1_12            8          505              0.50332
# 3922   SRN_2   SRN_2_11            7          521              0.51442
# 3923   SRN_3   SRN_3_11            9          208              0.21936
# 3924  UBN_10   UBN_10_1            1        63127             62.27446
# 3925   UBN_3    UBN_3_3            1        31218             30.10211
#
#       party_id                  mp_app_name            name
# ...

# %%
#สร้างตารางใหม่แสดง เขต ชื่อสส ชื่อพรรค คะแนนเสียง rank
result_constituencies_Top10_new=result_constituencies_Top10[['cons_id','mp_app_name','name','mp_app_vote','mp_app_rank']]

# %%
Ans_Q1=result_constituencies_Top10_new.sort_values(by=['cons_id','mp_app_rank'])

# %% [markdown]
# ###Ans Q1

# %%
Ans_Q1
# Out:
#      cons_id                mp_app_name             name  mp_app_vote  \
# 99     ACR_1     นางสุขสมรวย วันทนียกุล        ภูมิใจไทย        38275
# 2531   ACR_1          นางสมหญิง บัวบุตร         เพื่อไทย        21388
# 1821   ACR_1          นายประภาส เวชกรณ์          ก้าวไกล        16724
# 1434   ACR_1  นางสาวแป้งธนชาภา จันทวารา     ประชาธิปัตย์        15926
# 2931   ACR_1          นายวิชัย บุญเสริฐ     พลังประชารัฐ         2825
# ...      ...                        ...              ...          ...
# 2530   YST_3            นายสรวิศ เดชเสน      ไทยสร้างไทย         1498
# 1058   YST_3           นายพิทยา พาลุสุข  รวมไทยสร้างชาติ          821
# 1433   YST_3        นายชัยทัต วงศ์อินตา       เสรีรวมไทย          561
# 3345   YST_3         นายศรายุทธ สุดสวาท  ประชาธิปไตยใหม่          531
# 1820   YST_3     นางกฤตลดาณัช วงศ์จินดา     ประชาธิปัตย์          498
#
#       mp_app_rank
# 99              1
# 2531            2
# 1821            3
# 1434            4
# 2931            5
# ...

# %% [markdown]
# ###Q2
# create a table that shows a list of ELECTED constituency candidate names and their parties. Sort the table by voted they received and showed only 5 worst perform (30 points)

# %%
#ข้อมูลการเลือกตั้ง
result_constituencies_Candidate
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1   ACR_1_1            9          459              0.43477
# 1      ACR_1  ACR_1_10            1        38275             36.25419
# 2      ACR_1  ACR_1_11           13          126              0.11935
# 3      ACR_1  ACR_1_12           12          127              0.12029
# 4      ACR_1  ACR_1_13           11          212              0.20081
# ...      ...       ...          ...          ...                  ...
# 4776   YST_3   YST_3_5            1        37946             36.30085
# 4777   YST_3   YST_3_6            7          821              0.78541
# 4778   YST_3   YST_3_7            9          531              0.50798
# 4779   YST_3   YST_3_8           11          296              0.28317
# 4780   YST_3   YST_3_9            3        14502             13.87326
#
#       party_id
# 0          706
# 1          709
# 2          712
# 3          742
# 4          761
# ...        ...
# ...

# %%
Candidate_name #ชื่อสสแต่ละเขต

# %%
#หาชื่อของผู้ลงสมัครในแต่ละเขต
pd.merge(result_constituencies_Candidate , Candidate_name, on='mp_app_id')
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1   ACR_1_1            9          459              0.43477
# 1      ACR_1  ACR_1_10            1        38275             36.25419
# 2      ACR_1  ACR_1_11           13          126              0.11935
# 3      ACR_1  ACR_1_12           12          127              0.12029
# 4      ACR_1  ACR_1_13           11          212              0.20081
# ...      ...       ...          ...          ...                  ...
# 4776   YST_3   YST_3_5            1        37946             36.30085
# 4777   YST_3   YST_3_6            7          821              0.78541
# 4778   YST_3   YST_3_7            9          531              0.50798
# 4779   YST_3   YST_3_8           11          296              0.28317
# 4780   YST_3   YST_3_9            3        14502             13.87326
#
#       party_id             mp_app_name
# 0          706   นางสาวปิยะมาศ บัวแก้ว
# 1          709  นางสุขสมรวย วันทนียกุล
# ...

# %%
result_constituencies_Candidate_with_name= pd.merge(result_constituencies_Candidate , Candidate_name, on='mp_app_id')

# %%
party_name #ชื่อพรรค
# Out:
#     party_id           name
# 0        701   ประชาธิปัตย์
# 1        702     ประชากรไทย
# 2        703   ความหวังใหม่
# 3        705       เพื่อไทย
# 4        706  ชาติพัฒนากล้า
# ..       ...            ...
# 65       780    ไทยก้าวหน้า
# 66       781           พลัง
# 67       783  ชาติรุ่งเรือง
# 68       784       รวมใจไทย
# 69       786        เปลี่ยน
#
# [70 rows x 2 columns]

# %%
pd.merge(result_constituencies_Candidate_with_name, party_name, on='party_id') #รวมชื่อพรรคของสส แต่ละคนไปในตาราง
# Out:
#      cons_id  mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0      ACR_1    ACR_1_1            9          459              0.43477
# 1      BKK_1    BKK_1_9            7         1247              1.32088
# 2     BKK_10   BKK_10_1            7          751              0.72144
# 3     BKK_11  BKK_11_10            9          402              0.39176
# 4     BKK_12  BKK_12_14            7         1077              1.01212
# ...      ...        ...          ...          ...                  ...
# 4776   SRN_3   SRN_3_11            9          208              0.21936
# 4777   SRN_4   SRN_4_12           12          154              0.16518
# 4778  UBN_11  UBN_11_12           12          168              0.17959
# 4779  UBN_10   UBN_10_1            1        63127             62.27446
# 4780   UBN_3    UBN_3_3            1        31218             30.10211
#
#       party_id                  mp_app_name            name
# ...

# %%
All_result_constituencies=pd.merge(result_constituencies_Candidate_with_name, party_name, on='party_id') #ตารางใหม่ที่มีชื่อสส และชื่อพรรค

# %%
#สร้างตารางใหม่แสดง เขต ชื่อสส ชื่อพรรค คะแนนเสียง
All_result_constituencies_new = All_result_constituencies[['cons_id','mp_app_name','name','mp_app_vote']]

# %%
All_result_constituencies_new    #ข้อมูลผลการเลือกตั้งแบบแบ่งเขต
# Out:
#      cons_id                  mp_app_name            name  mp_app_vote
# 0      ACR_1        นางสาวปิยะมาศ บัวแก้ว   ชาติพัฒนากล้า          459
# 1      BKK_1   นายนันทพันธ์ ศุภณ์ภัทรพงศ์   ชาติพัฒนากล้า         1247
# 2     BKK_10  นายอรรถสิทธิ์ เหลืองไพบูลย์   ชาติพัฒนากล้า          751
# 3     BKK_11      นายวิโรจน์ จิตรอบอารีย์   ชาติพัฒนากล้า          402
# 4     BKK_12    นายโชคภิวัสร์ เลิศสุรสีห์   ชาติพัฒนากล้า         1077
# ...      ...                          ...             ...          ...
# 4776   SRN_3           นายสุพัฒน์ โพธิสาร     ไทยก้าวหน้า          208
# 4777   SRN_4        นายไพศาล ศิริปุญญะบุษ     ไทยก้าวหน้า          154
# 4778  UBN_11              นายฉัตรชัย คำใส     ไทยก้าวหน้า          168
# 4779  UBN_10         นายสมศักดิ์ บุญประชม  เพื่อไทรวมพลัง        63127
# 4780   UBN_3        นางพิมพกาญจน์ พลสมัคร  เพื่อไทรวมพลัง        31218
#
# [4781 rows x 4 columns]

# %%
#หารายชื่อของสสที่ได้คะแนนน้อยที่สุด 5 อันดับ ในแต่ละเขต

# %%
 #จัดกลุ่มโดยหมายเขตเขค โดนเรียง mp_app_vote จาก น้อยไปหามาก แล้วแสดงค่า 5 แถวแรกของแต่ละกลุ่ม
All_result_constituencies_new.sort_values(['cons_id','mp_app_vote'],ascending=True).groupby('cons_id').head(5)
# Out:
#      cons_id             mp_app_name             name  mp_app_vote
# 492    ACR_1     นายการันต์ ลุนพันธ์  ประชาธิปไตยใหม่          126
# 532    ACR_1          นายไสว ผลาวงศ์          คลองไทย          127
# 772    ACR_1        นายสงบ โสภิพันธ์    พลังสังคมใหม่          212
# 851    ACR_1          นายกมล บุญธิมา         ไทยภักดี          234
# 0      ACR_1   นางสาวปิยะมาศ บัวแก้ว    ชาติพัฒนากล้า          459
# ...      ...                     ...              ...          ...
# 1151   YST_3    นางสาวสุนันทา สีชมภู         ไทยภักดี          296
# 2351   YST_3  นางกฤตลดาณัช วงศ์จินดา     ประชาธิปัตย์          498
# 531    YST_3      นายศรายุทธ สุดสวาท  ประชาธิปไตยใหม่          531
# 1951   YST_3     นายชัยทัต วงศ์อินตา       เสรีรวมไทย          561
# 1551   YST_3        นายพิทยา พาลุสุข  รวมไทยสร้างชาติ          821
#
# [2000 rows x 4 columns]

# %%
Ans_Q2=All_result_constituencies_new.sort_values(['cons_id','mp_app_vote'],ascending=True).groupby('cons_id').head(5)

# %% [markdown]
# ###Ans Q2

# %%
Ans_Q2
# Out:
#      cons_id             mp_app_name             name  mp_app_vote
# 492    ACR_1     นายการันต์ ลุนพันธ์  ประชาธิปไตยใหม่          126
# 532    ACR_1          นายไสว ผลาวงศ์          คลองไทย          127
# 772    ACR_1        นายสงบ โสภิพันธ์    พลังสังคมใหม่          212
# 851    ACR_1          นายกมล บุญธิมา         ไทยภักดี          234
# 0      ACR_1   นางสาวปิยะมาศ บัวแก้ว    ชาติพัฒนากล้า          459
# ...      ...                     ...              ...          ...
# 1151   YST_3    นางสาวสุนันทา สีชมภู         ไทยภักดี          296
# 2351   YST_3  นางกฤตลดาณัช วงศ์จินดา     ประชาธิปัตย์          498
# 531    YST_3      นายศรายุทธ สุดสวาท  ประชาธิปไตยใหม่          531
# 1951   YST_3     นายชัยทัต วงศ์อินตา       เสรีรวมไทย          561
# 1551   YST_3        นายพิทยา พาลุสุข  รวมไทยสร้างชาติ          821
#
# [2000 rows x 4 columns]

# %% [markdown]
# ###Q3
# create a table from the party list vote result that shows the ratio between the vote recieved by the highest party and the second highest party of each constituency area.
#
#  ($\frac{V1}{V2}$ where $V1$ is the number of votes the highest paty received and $V2$ is the number of votes the second highest paty received)
#
# The table should include name of the constituency area, district, province, name of the top party, name of the runner-up party, and $\frac{V1}{V2}$
# (60 points)

# %%
#ผลการเลือกตั้งแบบบัญชีรายชื่อ
result_constituencies_PartyList
# Out:
#       cons_id  party_id  party_list_vote  party_list_vote_percent
# 0       ACR_1       701             4550                  4.30977
# 1       ACR_1       702              185                  0.17523
# 2       ACR_1       703               67                  0.06346
# 3       ACR_1       705            33576                 31.80328
# 4       ACR_1       706              132                  0.12503
# ...       ...       ...              ...                      ...
# 26795   YST_3       780              145                  0.13871
# 26796   YST_3       781              412                  0.39414
# 26797   YST_3       783               17                  0.01626
# 26798   YST_3       784              138                  0.13202
# 26799   YST_3       786               85                  0.08131
#
# [26800 rows x 4 columns]

# %%
#รวมชื่อพรรคเข้าไปในผลการเลือกตั้ง
pd.merge(result_constituencies_PartyList, party_name, on='party_id')
# Out:
#       cons_id  party_id  party_list_vote  party_list_vote_percent  \
# 0       ACR_1       701             4550                  4.30977
# 1       ACR_2       701             2362                  2.11246
# 2       ATG_1       701              747                  0.83226
# 3       ATG_2       701              559                  0.61116
# 4       AYA_1       701             1019                  0.92370
# ...       ...       ...              ...                      ...
# 26795   YLA_2       786               45                  0.04486
# 26796   YLA_3       786               84                  0.08575
# 26797   YST_1       786               62                  0.05611
# 26798   YST_2       786               53                  0.05384
# 26799   YST_3       786               85                  0.08131
#
#                name
# 0      ประชาธิปัตย์
# 1      ประชาธิปัตย์
# 2      ประชาธิปัตย์
# 3      ประชาธิปัตย์
# 4      ประชาธิปัตย์
# ...             ...
# 26795       เปลี่ยน
# ...

# %%
result_constituencies_PartyList_whith_name = pd.merge(result_constituencies_PartyList, party_name, on='party_id')

# %%
#สร้างตารางผลการเลือกตั้งใหม่ แสดงชเขต ชื่อพรรค คะแนนเสียง
result_constituencies_PartyList_whith_name[['cons_id','name','party_list_vote']]
# Out:
#       cons_id          name  party_list_vote
# 0       ACR_1  ประชาธิปัตย์             4550
# 1       ACR_2  ประชาธิปัตย์             2362
# 2       ATG_1  ประชาธิปัตย์              747
# 3       ATG_2  ประชาธิปัตย์              559
# 4       AYA_1  ประชาธิปัตย์             1019
# ...       ...           ...              ...
# 26795   YLA_2       เปลี่ยน               45
# 26796   YLA_3       เปลี่ยน               84
# 26797   YST_1       เปลี่ยน               62
# 26798   YST_2       เปลี่ยน               53
# 26799   YST_3       เปลี่ยน               85
#
# [26800 rows x 3 columns]

# %%
result_constituencies_PartyList_New = result_constituencies_PartyList_whith_name[['cons_id','name','party_list_vote']]

# %%
#หาพรรคที่ได้คะแนนเสียงลำดับที่ 1 และ 2 ของแต่ละเขต
result_constituencies_PartyList_New.sort_values(['cons_id','party_list_vote'],ascending=False).groupby('cons_id').head(2)
# Out:
#      cons_id      name  party_list_vote
# 1599   YST_3  เพื่อไทย            50543
# 8399   YST_3   ก้าวไกล            29942
# 1598   YST_2  เพื่อไทย            52600
# 8398   YST_2   ก้าวไกล            24011
# 1597   YST_1  เพื่อไทย            42534
# ...      ...       ...              ...
# 1202   ATG_1  เพื่อไทย            26853
# 1201   ACR_2  เพื่อไทย            36243
# 8001   ACR_2   ก้าวไกล            35581
# 8000   ACR_1   ก้าวไกล            33892
# 1200   ACR_1  เพื่อไทย            33576
#
# [800 rows x 3 columns]

# %%
#จะได้ตารางที่แสดงพรรคอันดับที่ 1 และ 2 ในแต่ละเขต
Partylist_1_2=result_constituencies_PartyList_New.sort_values(['cons_id','party_list_vote'],ascending=False).groupby('cons_id').head(2)

# %%
Partylist_1_2.sort_values('cons_id')
# Out:
#      cons_id      name  party_list_vote
# 1200   ACR_1  เพื่อไทย            33576
# 8000   ACR_1   ก้าวไกล            33892
# 1201   ACR_2  เพื่อไทย            36243
# 8001   ACR_2   ก้าวไกล            35581
# 8002   ATG_1   ก้าวไกล            35065
# ...      ...       ...              ...
# 1597   YST_1  เพื่อไทย            42534
# 8398   YST_2   ก้าวไกล            24011
# 1598   YST_2  เพื่อไทย            52600
# 8399   YST_3   ก้าวไกล            29942
# 1599   YST_3  เพื่อไทย            50543
#
# [800 rows x 3 columns]
